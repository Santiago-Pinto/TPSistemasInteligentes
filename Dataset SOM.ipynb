# %%
import pandas as pd
import numpy as np
#import shapely
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataFiltrada/wekaSOM4.csv',low_memory = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
# Unnamed: 0            50000 non-null int64
# barrio                50000 non-null object
# rooms                 50000 non-null float64
# bedrooms              50000 non-null float64
# bathrooms             50000 non-null float64
# surface_total         50000 non-null float64
# surface_covered       50000 non-null float64
# price                 50000 non-null float64
# dist_centro           50000 non-null float64
# min_dist_subte (m)    50000 non-null float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 3.8+ MB

# %%
df.sample(1000)
# Out:
#        Unnamed: 0         barrio  rooms  bedrooms  bathrooms  surface_total  \
# 40144       13170        Almagro    3.0       0.0        1.0           73.0
# 20483       41391      Balvanera    1.0       0.0        1.0           36.0
# 4841         6220        Almagro    2.0       1.0        1.0           42.0
# 6569        80880          Boedo    2.0       0.0        1.0           46.0
# 17588       27409        Almagro    2.0       1.0        1.0           51.0
# 4796        82367        Almagro    1.0       0.0        1.0           36.0
# 36710       25811        Almagro    2.0       1.0        1.0           41.0
# 33474      103788  San Cristobal    2.0       1.0        1.0           44.0
# 31190       42625        Almagro    2.0       1.0        1.0           37.0
# 19119       33570        Almagro    2.0       1.0        1.0           49.0
# 22480       96581       Recoleta    2.0       1.0        1.0           58.0
# ...
